# %%
import pandas as pd  #用于读取数据
import matplotlib
import matplotlib.pyplot as plt 
import numpy as np
import random

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ab610a96ffc1> in <module>()
#      15
#      16 # 添加纵横轴的刻度
# ---> 17 plt.yticks(index, ('2011', '2012', '2013', '2014', '2015',"2016","2017","2018","2019","2020"))
#      18 #plt.yticks(np.arange(0, 120000, 10))
#      19
#
# NameError: name 'index' is not defined

# %%
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 80像素/每英寸
plt.figure(figsize=(8, 6), dpi=80)

# # 再创建一个规格为 1 x 1 的子图
# plt.subplot(1, 1, 1)

# 柱子总数
N = 6
# 包含每个柱子对应值的序列
values = (25, 32, 34, 20, 41, 50)


# 包含每个柱子下标的序列
index = np.arange(N)

# 柱子的宽度
width = 0.35

# 绘制柱状图, 每根柱子的颜色为紫罗兰色
p2 = plt.bar(index, values, width, label="网销基金规模 (亿元)", color="#87CEFA")

# 设置横轴标签
plt.xlabel('Months')
# 设置纵轴标签
plt.ylabel('网销基金规模 (亿元)')

# 添加标题
plt.title('中国公募集基金互联网销售规模')


#年份数据。
year_name = ['2018', '2017', '2016', '2015', '2014']
 
#数组反转。
year_name.reverse()

# 添加纵横轴的刻度
plt.xticks(index, ('2018', '2017', '2016', '2015', '2014',"2013"))
plt.yticks(np.arange(0, 81, 10))

# 添加图例
plt.legend(loc="upper right")

plt.show()

# %%
type(data)
# Out:
# numpy.ndarray

# %%
from matplotlib.pyplot import MultipleLocator
plt.figure(figsize=(64,10), dpi=80)


fig, ax1 = plt.subplots() # 官网查询代码，接收ax1
plt.xlim(-0.5,19)


#bottom_x = ['Middleton', 'Cole', 'Nguyen', 'Lewis', 'Martin', 'Hoffman']
bottom_x = ['2002',"2003",'2004', '2005', '2006', '2007', '2008',"2009","2010",'2011', '2012', '2013', '2014', '2015',"2016","2017","2018","2019","2020"]
left_y1 = [18000, 18000,18000, 18000, 20000, 25000,27000,28000,30000,50000, 45000, 60000, 90000, 110000, 140000,150000,150000,150000,160000]
right_y = [200, 200, 200, 200, 500, 500, 600, 1000, 1400,1700, 2000,2200,2800,3500,3800,4000,4500,5000,5500]
top_x = ['Tatemouth', 'West Erika', 'Bonillaview', 'Lake Leslieland', 'New Shawn', 'Bendermouth',
         'Tatemouth', 'West Erika', 'Bonillaview', 'Lake Leslieland', 'New Shawn', 'Bendermouth', 'New Shawn', 'Bendermouth']

x_indexes = np.arange(len(bottom_x)) #19
x_major_locator=MultipleLocator(1)

width = 0.35

ax1.bar(x_indexes, left_y1, width=width,   )
# ax1.bar(x_indexes, left_y2, width=width)
# ax1.bar(x_indexes+width, left_y1, width=width)

ax2 = ax1.twinx()

#ax2.plot(bottom_x, right_y, linewidth=4, marker='*',color='r', linestyle='-.')
ax2.plot(bottom_x, right_y, linewidth=3, marker='.',color='yellow', linestyle='-.',markersize=12)
#ax2.title('My exercise')
plt.title('中国公募集基金互联网销售规模')
# 设置横轴标签
plt.xlabel('年')
# 设置纵轴标签
plt.ylabel('公募基金数量')
#plt.ylabel('公募基金规模 (亿元)')
ax2.set_ylabel('公募基金规模 (亿元)')


# 添加图例
ax1.legend(loc="upper center")

# ax1.ylabel('Sallary of Employee (k)')
# plt.title('My exercise')
# ax1.xticks(ticks= x_indexes, labels= bottom_x)
plt.ylim(0, 6000)
plt.savefig("pic5.png")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from matplotlib.pyplot import MultipleLocator
plt.figure(figsize=(64,10), dpi=80)


fig, ax1 = plt.subplots() # 官网查询代码，接收ax1
plt.xlim(-0.5,14)


#bottom_x = ['Middleton', 'Cole', 'Nguyen', 'Lewis', 'Martin', 'Hoffman']
bottom_x = ['2007', '2008',"2009","2010",'2011', '2012', '2013', '2014', '2015',"2016","2017","2018","2019","2020"]
left_y1 = [27000,27000,28000,30000,50000, 45000, 60000, 90000, 110000, 140000,150000,150000,150000,160000]
right_y = [500, 600, 1000, 1400,1700, 2000,2200,2800,3500,3800,4000,4500,5000,5500]
top_x = ['Tatemouth', 'West Erika', 'Bonillaview', 'Lake Leslieland', 'New Shawn', 'Bendermouth',
         'Tatemouth', 'West Erika', 'Bonillaview', 'Lake Leslieland', 'New Shawn', 'Bendermouth', 'New Shawn', 'Bendermouth']

x_indexes = np.arange(len(bottom_x)) #19
x_major_locator=MultipleLocator(1)

width = 0.35

ax1.bar(x_indexes, left_y1, width=width,   )
# ax1.bar(x_indexes, left_y2, width=width)
# ax1.bar(x_indexes+width, left_y1, width=width)

ax2 = ax1.twinx()

#ax2.plot(bottom_x, right_y, linewidth=4, marker='*',color='r', linestyle='-.')
ax2.plot(bottom_x, right_y, linewidth=3, marker='.',color='yellow', linestyle='-.',markersize=12)
#ax2.title('My exercise')
plt.title('中国公募集基金互联网销售规模')
# 设置横轴标签
plt.xlabel('年')
# 设置纵轴标签
plt.ylabel('公募基金数量')
#plt.ylabel('公募基金规模 (亿元)')
ax1.set_ylabel('公募基金规模 (亿元)')


# 添加图例
#ax2.legend(loc="upper center")

# ax1.ylabel('Sallary of Employee (k)')
# plt.title('My exercise')
# ax1.xticks(ticks= x_indexes, labels= bottom_x)
plt.ylim(0, 6000)
plt.savefig("pic5.png")
plt.show()

# %%
# 中文乱码和坐标轴负号处理。
matplotlib.rc('font', family='SimHei', weight='bold')
plt.rcParams['axes.unicode_minus'] = False
 
#城市数据。
city_name = ['2018', '2017', '2016', '2015', '2014']
 
#数组反转。
city_name.reverse()
 
#装载随机数据。
data = []
for i in range(len(city_name)):
        data.append(random.randint(100, 150))
        


#绘图。
fig, ax = plt.subplots()
b = ax.barh(range(len(city_name)), data, color='#87CEFA')



# # 柱子的宽度
# width = 0.35

# # 绘制柱状图, 每根柱子的颜色为紫罗兰色
# p2 = plt.bar(index, values, width, label="网销基金规模 (亿元)", color="#87CEFA")



 
#为横向水平的柱图右侧添加数据标签。
for rect in b:
    w = rect.get_width()
    ax.text(w, rect.get_y()+rect.get_height()/2, '%d' %
            int(w), ha='left', va='center')
 
#设置Y轴纵坐标上的刻度线标签。
ax.set_yticks(range(len(city_name)))
ax.set_yticklabels(city_name)
 
#不要X横坐标上的label标签。
plt.xticks(())
 
plt.title('中国公募集基金互联网销售规模', loc='center', fontsize='15AssertionError',
          fontweight='bold', color='black')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/envs/Chatbot/lib/python3.5/site-packages/matplotlib/font_manager.py in set_size(self, size)
#     879         try:
# --> 880             size = float(size)
#     881         except ValueError:
#
# ValueError: could not convert string to float: '15AssertionError'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/envs/Chatbot/lib/python3.5/site-packages/matplotlib/font_manager.py in set_size(self, size)
#     882             try:
# --> 883                 scale = font_scalings[size]
#     884             except KeyError:
#
# KeyError: '15AssertionError'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import math
x1=[20,33,51,79,101,121,132,145,162,182,203,219,232,243,256,270,287,310,325]
y1=[49,48,48,48,48,87,106,123,155,191,233,261,560,684,897,1007,1370,1380,1892]
x2=[31,52,73,92,101,112,126,140,153,175,186,196,215,230,240,270,288,300]
y2=[48,48,48,48,49,89,162,237,302,378,443,472,522,597,628,1661,1690,1892]
x3=[30,50,70,90,105,114,128,137,147,159,170,180,190,200,210,230,243,259,284,297,311]
y3=[48,48,48,48,66,173,351,472,586,712,804,899,994,1094,1198,1360,1458,1578,1734,1797,1892]
x=np.arange(20,350)
l1=plt.plot(x1,y1,'r--',label='用户')
l2=plt.plot(x2,y2,'g--',label='风控')
l3=plt.plot(x3,y3,'b--',label='投研')
plt.plot(x1,y1,'ro-',x2,y2,'g+-',x3,y3,'b^-')
plt.title('基金行业数字化渗透成熟度曲线预测')
# plt.xlabel('row')
plt.ylabel('数字化成熟度')
#plt.xticks(index, ('规范发展阶段', '稳定发展阶段', '创新发展阶段', '中期', '后期',"新型金融阶段"))
# plt.xlim(-0.5,100)

# x = np.arange(-10, 10, 0.1)
# y = []
# for t in x:
#     y_1 = 1 / (1 + math.exp(-t))
#     y.append(y_1)
# plt.plot(x, y, label="sigmoid")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.ylim(0, 1)



plt.legend()
plt.show()

# %%
x1=[20,33,51,79,101,121,132,145,162,182,203,219,232,243,256,270,287,310,325]
y1=[49,48,48,48,48,87,106,123,155,191,233,300,278,270,800,1000,1341,1569,1841]
x2=[31,52,73,92,101,112,126,140,153,175,186,196,215,230,240,270,288,300]
y2=[48,48,48,48,49,89,162,237,302,378,443,472,522,597,628,1641,1690,1702]
x3=[30,50,70,90,105,114,128,137,147,159,170,180,190,200,210,230,243,259,284,297,311]
x4=[30,50,70,90,105,114,128,137,147,159,170,180,190,200,210,230,243,259,284,297,311]
y3=[48,48,48,48,66,173,351,472,586,712,804,899,994,1094,1198,1360,1458,1578,1734,1797,1892]
y4=[38,38,38,38,56,153,341,462,576,702,794,889,984,1094,1198,1360,1458,1578,1734,1797,1892]
x=np.arange(20,350)
l1=plt.plot(x1,y1,'b--',label='用户')
l2=plt.plot(x2,y2,'g--',label='风控')
l3=plt.plot(x3,y3,'y--',label='投研')
l4=plt.plot(x4,y4,'p--',label='内部管理')
plt.plot(x1,y1,'bo-',x2,y2,'g+-',x3,y3,'y^-',x4,y4,'p--')
plt.title('基金行业数字化渗透成熟度曲线预测')
# plt.xlabel('row')
plt.ylabel('数字化成熟度')

plt.legend()

# %%
# 中文乱码和坐标轴负号处理。
matplotlib.rc('font', family='SimHei', weight='bold')
plt.rcParams['axes.unicode_minus'] = False
 
#城市数据。
city_name = ['2018', '2017', '2016', '2015', '2014']
 
#数组反转。
city_name.reverse()
 
#装载随机数据。
data = []
for i in range(len(city_name)):
        data.append(random.randint(100, 150))
        


#绘图。
fig, ax = plt.subplots()
b = ax.barh(range(len(city_name)), data, color='#87CEFA')



# # 柱子的宽度
# width = 0.35

# # 绘制柱状图, 每根柱子的颜色为紫罗兰色
# p2 = plt.bar(index, values, width, label="网销基金规模 (亿元)", color="#87CEFA")



 
#为横向水平的柱图右侧添加数据标签。
for rect in b:
    w = rect.get_width()
    ax.text(w, rect.get_y()+rect.get_height()/2, '%d' %
            int(w), ha='left', va='center')
 
#设置Y轴纵坐标上的刻度线标签。
ax.set_yticks(range(len(city_name)))
ax.set_yticklabels(city_name)
 
#不要X横坐标上的label标签。
plt.xticks(())
 
plt.title('中国公募集基金互联网销售规模', loc='center', fontsize='15AssertionError',
          fontweight='bold', color='black')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Applications/anaconda3/envs/Chatbot/lib/python3.5/site-packages/matplotlib/font_manager.py in set_size(self, size)
#     879         try:
# --> 880             size = float(size)
#     881         except ValueError:
#
# ValueError: could not convert string to float: '15AssertionError'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/envs/Chatbot/lib/python3.5/site-packages/matplotlib/font_manager.py in set_size(self, size)
#     882             try:
# --> 883                 scale = font_scalings[size]
#     884             except KeyError:
#
# KeyError: '15AssertionError'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
plt.figure(figsize=(8, 6), dpi=80)


# 添加标题
plt.title('中国公募集基金互联网销售规模')


plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签 
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

#data = np.random.randint(10,120000,size=8)

data = np.array([28000,30000,30000,35000,64900,65000,95000,98000,10000])

width  =0.5
plt.barh(np.arange(data.size), data, width,label="网销基金规模 (亿元 人民币)", color="#87CEFA")

# 添加纵横轴的刻度
plt.yticks(index, ('2011', '2012', '2013', '2014', '2015',"2016","2017","2018","2019","2020"))
#plt.yticks(np.arange(0, 120000, 10))

plt.legend()
plt.show()

plt.savefig("基金.png")


type(data)
# Out:
# numpy.ndarray
